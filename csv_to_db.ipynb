# %%
pip install pandas sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
df = pd.read_csv(r'C:\Users\KADYRBEK\Downloads\credit_risk_dataset.csv\credit_risk_dataset.csv')
engine = create_engine('sqlite:///mydatabase.db')
df.to_sql('my_table', con=engine, if_exists='replace', index=False)
# Out:
# 32581

# %%
df = pd.read_csv(r'C:\Users\KADYRBEK\Downloads\credit_risk_dataset.csv\credit_risk_dataset.csv')
engine = create_engine('sqlite:///credit_risk.db')
df.to_sql('loans', con=engine, if_exists='replace', index=False)
print(f"Загружено {len(df)} записей в таблицу 'loans'")
# Out:
# Загружено 32581 записей в таблицу 'loans'
